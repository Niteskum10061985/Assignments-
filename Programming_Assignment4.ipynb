# %%
1.	Write a Python Program to Find the Factorial of a Number?
    def inputnumber(a):
    """Program to Find the Factorial of a Number"""
        try:
            l=[]
            for i in range(1,a+1):
                if a%i == 0:
                    l.append(i)
            print('Factor of number',a,':',l)
        except Exception as e:
            print(e)

2.	Write a Python Program to Display the multiplication Table?
    def multiplication(a):
        """Program to Display the multiplication Table"""
        try:
            for i in range(1,11):
                print(a,'*',i,'=',(a*i))
        except Exception as e:
            print(e)

3.	Write a Python Program to Print the Fibonacci sequence?
    def fibonacci(z):
        """Program to Print the Fibonacci sequence, 'z' represents the range to which the series is required"""
        try:
            a= 0
            b= 1
            for i in range(1,z):
                a,b=b,b+a
                print(a)
        except Expection as e:
            print(e)
            
    ###Using Yield function
    def fibonacci(z):
    """Program to Print the Fibonacci sequence, 'z' represents the range to which the series is required"""
    try:
        a= 0
        b= 1
        for i in range(1,z):
            a,b=b,b+a
            yield a
    except Expection as e:
            print(e)
    
    for i in fibonacci(1000):
        print(i)
    

4.	Write a Python Program to Check Armstrong Number?
    def inputnumber(m):
    """Program to Check Armstrong Number"""
        try:
            n=str(m)
            k = 0
            l=list(n)
            a=len(l)
            for i in range(a):
                k = k + int(l[i])**a
            if m == k:
                print(m,'is armstrong number')
            else:
                print(m,'is not armstrong number')
        except Exception as e:
            print(e)


5.	Write a Python Program to Find Armstrong Number in an Interval?
    def inputnumber(c,m):
    """Program to Check Armstrong Number"""
        try:
            lst =[]
            for i in range(c,m+1):
                n=str(i)
                k = 0
                l=list(n)
                a=len(l)
                for j in range(a):
                    k = k + int(l[j])**a
                if i == k:
                    lst.append(i)
            print('Armstrong number list in range',[c,m],'is' ,lst)
        except Exception as e:
            print(e)



6.	Write a Python Program to Find the Sum of Natural Numbers?
    def sumofnat(s):
    """Program to Find the Sum of Natural Numbers"""
        try:
            k=0
            for i in range(s):
                k = k+i
            print(k)
        except Exception as e:
            print(e)
